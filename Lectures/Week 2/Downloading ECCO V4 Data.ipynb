# %% [markdown]
# # Downloading ECCO V4 Data
#
# Author: Mike Wood
#
# This notebook is designed to download ECCO data from the [ECCO Drive](https://ecco.jpl.nasa.gov/drive/).
#
# Note that you must have a [NASA Earthdata](https://www.earthdata.nasa.gov/) account. If you don't already have one, be sure to make one before using this notebook.
#
# When you first navigate to the [ECCO Drive](https://ecco.jpl.nasa.gov/drive/), you will be directed to a page with your WebDAV/Programmatic API credentials - these will be used when prompted for your credentials below.
#
# #### Import the modules for this notebook

# %%
import requests
from requests.auth import HTTPBasicAuth
import os

# %% [markdown]
# #### Define the destination file path

# %%
# define the path to the folder where the data will be downloaded
download_folder = '/Volumes/T7/MLML/ms274_fall2025/Data'

# %% [markdown]
# #### Define the data request

# %%
# choose an ECCO version and release
version = 'Version4' #e.g. Version4
release = 'Release4' #e.g. Release4

# choose a subset
subset = 'interp_monthly' #e.g. interp_monthly

# choose the variable to download
var_name = 'SSHDYN' # e.g. SSHDYN

# choose a start year and end year (in range 1992-2017)
start_year = 1992
end_year = 2017

# %% [markdown]
# #### Make a list of file paths
# Nothing to do here - just run this cell to generate the list.

# %%
# define the base url
base_url = 'https://ecco.jpl.nasa.gov/drive/files/'+version+'/'+release+'/'+subset+'/'+var_name

# make a list of URls corresponding to the file dates
file_urls = []
for year in range(start_year,end_year+1):
    for month in range(1,13):
        yr = str(year)
        mo = '{:02d}'.format(month)
        file_name = var_name+'_'+yr+'_'+mo+'.nc'
        file_urls.append(base_url+'/'+str(year)+'/'+file_name)

# %% [markdown]
# #### Download the data

# %%
print('Enter your WebDAV/Programmatic API credentials')
username = input('Enter your username: ')
password = input('Enter your password: ')

# check that all of the subdirectories are created
if version not in os.listdir(download_folder):
    os.mkdir(os.path.join(download_folder,version))
if release not in os.listdir(os.path.join(download_folder,version)):
    os.mkdir(os.path.join(download_folder,version,release))
if subset not in os.listdir(os.path.join(download_folder,version,release)):
    os.mkdir(os.path.join(download_folder,version,release,subset))
if var_name not in os.listdir(os.path.join(download_folder,version,release,subset)):
    os.mkdir(os.path.join(download_folder,version,release,subset,var_name))

# download all of the data
for i in range(len(file_urls)):
    url = file_urls[i]
    file_name = url.split('/')[-1]
    if file_name not in os.listdir(os.path.join(download_folder,version,release,subset,var_name)):
        print('Downloading '+file_name+' (file '+str(i+1)+' of '+str(len(file_urls))+')')
        output_file = os.path.join(download_folder,version,release,subset,var_name,file_name)
        with requests.get(url, stream=True, allow_redirects=True, auth=HTTPBasicAuth(username, password)) as r:
            r.raise_for_status()
            with open(output_file, 'wb') as f:                   
                for chunk in r.iter_content(chunk_size=8192):   
                    f.write(chunk)
# Out:
# Enter your WebDAV/Programmatic API credentials
# Enter your username:  brandoncastillo
# Enter your password:  025D7a9zG8Oa2IwqycR
# Downloading SSHDYN_1992_01.nc (file 1 of 312)
# Downloading SSHDYN_1992_02.nc (file 2 of 312)
# Downloading SSHDYN_1992_03.nc (file 3 of 312)
# Downloading SSHDYN_1992_04.nc (file 4 of 312)
# Downloading SSHDYN_1992_05.nc (file 5 of 312)
# Downloading SSHDYN_1992_06.nc (file 6 of 312)
# Downloading SSHDYN_1992_07.nc (file 7 of 312)
# Downloading SSHDYN_1992_08.nc (file 8 of 312)
# Downloading SSHDYN_1992_09.nc (file 9 of 312)
# Downloading SSHDYN_1992_10.nc (file 10 of 312)
# Downloading SSHDYN_1992_11.nc (file 11 of 312)
# Downloading SSHDYN_1992_12.nc (file 12 of 312)
# Downloading SSHDYN_1993_01.nc (file 13 of 312)
# Downloading SSHDYN_1993_02.nc (file 14 of 312)
# Downloading SSHDYN_1993_03.nc (file 15 of 312)
# Downloading SSHDYN_1993_04.nc (file 16 of 312)
# Downloading SSHDYN_1993_05.nc (file 17 of 312)
# Downloading SSHDYN_1993_06.nc (file 18 of 312)
# Downloading SSHDYN_1993_07.nc (file 19 of 312)
# Downloading SSHDYN_1993_08.nc (file 20 of 312)
# Downloading SSHDYN_1993_09.nc (file 21 of 312)
# Downloading SSHDYN_1993_10.nc (file 22 of 312)
# Downloading SSHDYN_1993_11.nc (file 23 of 312)
# Downloading SSHDYN_1993_12.nc (file 24 of 312)
# Downloading SSHDYN_1994_01.nc (file 25 of 312)
# Downloading SSHDYN_1994_02.nc (file 26 of 312)
# Downloading SSHDYN_1994_03.nc (file 27 of 312)
# Downloading SSHDYN_1994_04.nc (file 28 of 312)
# Downloading SSHDYN_1994_05.nc (file 29 of 312)
# Downloading SSHDYN_1994_06.nc (file 30 of 312)
# Downloading SSHDYN_1994_07.nc (file 31 of 312)
# Downloading SSHDYN_1994_08.nc (file 32 of 312)
# Downloading SSHDYN_1994_09.nc (file 33 of 312)
# Downloading SSHDYN_1994_10.nc (file 34 of 312)
# Downloading SSHDYN_1994_11.nc (file 35 of 312)
# Downloading SSHDYN_1994_12.nc (file 36 of 312)
# Downloading SSHDYN_1995_01.nc (file 37 of 312)
# Downloading SSHDYN_1995_02.nc (file 38 of 312)
# Downloading SSHDYN_1995_03.nc (file 39 of 312)
# Downloading SSHDYN_1995_04.nc (file 40 of 312)
# Downloading SSHDYN_1995_05.nc (file 41 of 312)
# Downloading SSHDYN_1995_06.nc (file 42 of 312)
# Downloading SSHDYN_1995_07.nc (file 43 of 312)
# Downloading SSHDYN_1995_08.nc (file 44 of 312)
# Downloading SSHDYN_1995_09.nc (file 45 of 312)
# Downloading SSHDYN_1995_10.nc (file 46 of 312)
# Downloading SSHDYN_1995_11.nc (file 47 of 312)
# Downloading SSHDYN_1995_12.nc (file 48 of 312)
# Downloading SSHDYN_1996_01.nc (file 49 of 312)
# Downloading SSHDYN_1996_02.nc (file 50 of 312)
# Downloading SSHDYN_1996_03.nc (file 51 of 312)
# Downloading SSHDYN_1996_04.nc (file 52 of 312)
# Downloading SSHDYN_1996_05.nc (file 53 of 312)
# Downloading SSHDYN_1996_06.nc (file 54 of 312)
# Downloading SSHDYN_1996_07.nc (file 55 of 312)
# Downloading SSHDYN_1996_08.nc (file 56 of 312)
# Downloading SSHDYN_1996_09.nc (file 57 of 312)
# Downloading SSHDYN_1996_10.nc (file 58 of 312)
# Downloading SSHDYN_1996_11.nc (file 59 of 312)
# Downloading SSHDYN_1996_12.nc (file 60 of 312)
# Downloading SSHDYN_1997_01.nc (file 61 of 312)
# Downloading SSHDYN_1997_02.nc (file 62 of 312)
# Downloading SSHDYN_1997_03.nc (file 63 of 312)
# Downloading SSHDYN_1997_04.nc (file 64 of 312)
# Downloading SSHDYN_1997_05.nc (file 65 of 312)
# Downloading SSHDYN_1997_06.nc (file 66 of 312)
# Downloading SSHDYN_1997_07.nc (file 67 of 312)
# Downloading SSHDYN_1997_08.nc (file 68 of 312)
# Downloading SSHDYN_1997_09.nc (file 69 of 312)
# Downloading SSHDYN_1997_10.nc (file 70 of 312)
# Downloading SSHDYN_1997_11.nc (file 71 of 312)
# Downloading SSHDYN_1997_12.nc (file 72 of 312)
# Downloading SSHDYN_1998_01.nc (file 73 of 312)
# Downloading SSHDYN_1998_02.nc (file 74 of 312)
# Downloading SSHDYN_1998_03.nc (file 75 of 312)
# Downloading SSHDYN_1998_04.nc (file 76 of 312)
# Downloading SSHDYN_1998_05.nc (file 77 of 312)
# Downloading SSHDYN_1998_06.nc (file 78 of 312)
# Downloading SSHDYN_1998_07.nc (file 79 of 312)
# Downloading SSHDYN_1998_08.nc (file 80 of 312)
# Downloading SSHDYN_1998_09.nc (file 81 of 312)
# Downloading SSHDYN_1998_10.nc (file 82 of 312)
# Downloading SSHDYN_1998_11.nc (file 83 of 312)
# Downloading SSHDYN_1998_12.nc (file 84 of 312)
# Downloading SSHDYN_1999_01.nc (file 85 of 312)
# Downloading SSHDYN_1999_02.nc (file 86 of 312)
# Downloading SSHDYN_1999_03.nc (file 87 of 312)
# Downloading SSHDYN_1999_04.nc (file 88 of 312)
# Downloading SSHDYN_1999_05.nc (file 89 of 312)
# Downloading SSHDYN_1999_06.nc (file 90 of 312)
# Downloading SSHDYN_1999_07.nc (file 91 of 312)
# Downloading SSHDYN_1999_08.nc (file 92 of 312)
# Downloading SSHDYN_1999_09.nc (file 93 of 312)
# Downloading SSHDYN_1999_10.nc (file 94 of 312)
# Downloading SSHDYN_1999_11.nc (file 95 of 312)
# Downloading SSHDYN_1999_12.nc (file 96 of 312)
# Downloading SSHDYN_2000_01.nc (file 97 of 312)
# Downloading SSHDYN_2000_02.nc (file 98 of 312)
# Downloading SSHDYN_2000_03.nc (file 99 of 312)
# Downloading SSHDYN_2000_04.nc (file 100 of 312)
# Downloading SSHDYN_2000_05.nc (file 101 of 312)
# Downloading SSHDYN_2000_06.nc (file 102 of 312)
# Downloading SSHDYN_2000_07.nc (file 103 of 312)
# Downloading SSHDYN_2000_08.nc (file 104 of 312)
# Downloading SSHDYN_2000_09.nc (file 105 of 312)
# Downloading SSHDYN_2000_10.nc (file 106 of 312)
# Downloading SSHDYN_2000_11.nc (file 107 of 312)
# Downloading SSHDYN_2000_12.nc (file 108 of 312)
# Downloading SSHDYN_2001_01.nc (file 109 of 312)
# Downloading SSHDYN_2001_02.nc (file 110 of 312)
# Downloading SSHDYN_2001_03.nc (file 111 of 312)
# Downloading SSHDYN_2001_04.nc (file 112 of 312)
# Downloading SSHDYN_2001_05.nc (file 113 of 312)
# Downloading SSHDYN_2001_06.nc (file 114 of 312)
# Downloading SSHDYN_2001_07.nc (file 115 of 312)
# Downloading SSHDYN_2001_08.nc (file 116 of 312)
# Downloading SSHDYN_2001_09.nc (file 117 of 312)
# Downloading SSHDYN_2001_10.nc (file 118 of 312)
# Downloading SSHDYN_2001_11.nc (file 119 of 312)
# Downloading SSHDYN_2001_12.nc (file 120 of 312)
# Downloading SSHDYN_2002_01.nc (file 121 of 312)
# Downloading SSHDYN_2002_02.nc (file 122 of 312)
# Downloading SSHDYN_2002_03.nc (file 123 of 312)
# Downloading SSHDYN_2002_04.nc (file 124 of 312)
# Downloading SSHDYN_2002_05.nc (file 125 of 312)
# Downloading SSHDYN_2002_06.nc (file 126 of 312)
# Downloading SSHDYN_2002_07.nc (file 127 of 312)
# Downloading SSHDYN_2002_08.nc (file 128 of 312)
# Downloading SSHDYN_2002_09.nc (file 129 of 312)
# Downloading SSHDYN_2002_10.nc (file 130 of 312)
# Downloading SSHDYN_2002_11.nc (file 131 of 312)
# Downloading SSHDYN_2002_12.nc (file 132 of 312)
# Downloading SSHDYN_2003_01.nc (file 133 of 312)
# Downloading SSHDYN_2003_02.nc (file 134 of 312)
# Downloading SSHDYN_2003_03.nc (file 135 of 312)
# Downloading SSHDYN_2003_04.nc (file 136 of 312)
# Downloading SSHDYN_2003_05.nc (file 137 of 312)
# Downloading SSHDYN_2003_06.nc (file 138 of 312)
# Downloading SSHDYN_2003_07.nc (file 139 of 312)
# Downloading SSHDYN_2003_08.nc (file 140 of 312)
# Downloading SSHDYN_2003_09.nc (file 141 of 312)
# Downloading SSHDYN_2003_10.nc (file 142 of 312)
# Downloading SSHDYN_2003_11.nc (file 143 of 312)
# Downloading SSHDYN_2003_12.nc (file 144 of 312)
# Downloading SSHDYN_2004_01.nc (file 145 of 312)
# Downloading SSHDYN_2004_02.nc (file 146 of 312)
# Downloading SSHDYN_2004_03.nc (file 147 of 312)
# Downloading SSHDYN_2004_04.nc (file 148 of 312)
# Downloading SSHDYN_2004_05.nc (file 149 of 312)
# Downloading SSHDYN_2004_06.nc (file 150 of 312)
# Downloading SSHDYN_2004_07.nc (file 151 of 312)
# Downloading SSHDYN_2004_08.nc (file 152 of 312)
# Downloading SSHDYN_2004_09.nc (file 153 of 312)
# Downloading SSHDYN_2004_10.nc (file 154 of 312)
# Downloading SSHDYN_2004_11.nc (file 155 of 312)
# Downloading SSHDYN_2004_12.nc (file 156 of 312)
# Downloading SSHDYN_2005_01.nc (file 157 of 312)
# Downloading SSHDYN_2005_02.nc (file 158 of 312)
# Downloading SSHDYN_2005_03.nc (file 159 of 312)
# Downloading SSHDYN_2005_04.nc (file 160 of 312)
# Downloading SSHDYN_2005_05.nc (file 161 of 312)
# Downloading SSHDYN_2005_06.nc (file 162 of 312)
# Downloading SSHDYN_2005_07.nc (file 163 of 312)
# Downloading SSHDYN_2005_08.nc (file 164 of 312)
# Downloading SSHDYN_2005_09.nc (file 165 of 312)
# Downloading SSHDYN_2005_10.nc (file 166 of 312)
# Downloading SSHDYN_2005_11.nc (file 167 of 312)
# Downloading SSHDYN_2005_12.nc (file 168 of 312)
# Downloading SSHDYN_2006_01.nc (file 169 of 312)
# Downloading SSHDYN_2006_02.nc (file 170 of 312)
# Downloading SSHDYN_2006_03.nc (file 171 of 312)
# Downloading SSHDYN_2006_04.nc (file 172 of 312)
# Downloading SSHDYN_2006_05.nc (file 173 of 312)
# Downloading SSHDYN_2006_06.nc (file 174 of 312)
# Downloading SSHDYN_2006_07.nc (file 175 of 312)
# Downloading SSHDYN_2006_08.nc (file 176 of 312)
# Downloading SSHDYN_2006_09.nc (file 177 of 312)
# Downloading SSHDYN_2006_10.nc (file 178 of 312)
# Downloading SSHDYN_2006_11.nc (file 179 of 312)
# Downloading SSHDYN_2006_12.nc (file 180 of 312)
# Downloading SSHDYN_2007_01.nc (file 181 of 312)
# Downloading SSHDYN_2007_02.nc (file 182 of 312)
# Downloading SSHDYN_2007_03.nc (file 183 of 312)
# Downloading SSHDYN_2007_04.nc (file 184 of 312)
# Downloading SSHDYN_2007_05.nc (file 185 of 312)
# Downloading SSHDYN_2007_06.nc (file 186 of 312)
# Downloading SSHDYN_2007_07.nc (file 187 of 312)
# Downloading SSHDYN_2007_08.nc (file 188 of 312)
# Downloading SSHDYN_2007_09.nc (file 189 of 312)
# Downloading SSHDYN_2007_10.nc (file 190 of 312)
# Downloading SSHDYN_2007_11.nc (file 191 of 312)
# Downloading SSHDYN_2007_12.nc (file 192 of 312)
# Downloading SSHDYN_2008_01.nc (file 193 of 312)
# Downloading SSHDYN_2008_02.nc (file 194 of 312)
# Downloading SSHDYN_2008_03.nc (file 195 of 312)
# Downloading SSHDYN_2008_04.nc (file 196 of 312)
# Downloading SSHDYN_2008_05.nc (file 197 of 312)
# Downloading SSHDYN_2008_06.nc (file 198 of 312)
# Downloading SSHDYN_2008_07.nc (file 199 of 312)
# Downloading SSHDYN_2008_08.nc (file 200 of 312)
# Downloading SSHDYN_2008_09.nc (file 201 of 312)
# Downloading SSHDYN_2008_10.nc (file 202 of 312)
# Downloading SSHDYN_2008_11.nc (file 203 of 312)
# Downloading SSHDYN_2008_12.nc (file 204 of 312)
# Downloading SSHDYN_2009_01.nc (file 205 of 312)
# Downloading SSHDYN_2009_02.nc (file 206 of 312)
# Downloading SSHDYN_2009_03.nc (file 207 of 312)
# Downloading SSHDYN_2009_04.nc (file 208 of 312)
# Downloading SSHDYN_2009_05.nc (file 209 of 312)
# Downloading SSHDYN_2009_06.nc (file 210 of 312)
# Downloading SSHDYN_2009_07.nc (file 211 of 312)
# Downloading SSHDYN_2009_08.nc (file 212 of 312)
# Downloading SSHDYN_2009_09.nc (file 213 of 312)
# Downloading SSHDYN_2009_10.nc (file 214 of 312)
# Downloading SSHDYN_2009_11.nc (file 215 of 312)
# Downloading SSHDYN_2009_12.nc (file 216 of 312)
# Downloading SSHDYN_2010_01.nc (file 217 of 312)
# Downloading SSHDYN_2010_02.nc (file 218 of 312)
# Downloading SSHDYN_2010_03.nc (file 219 of 312)
# Downloading SSHDYN_2010_04.nc (file 220 of 312)
# Downloading SSHDYN_2010_05.nc (file 221 of 312)
# Downloading SSHDYN_2010_06.nc (file 222 of 312)
# Downloading SSHDYN_2010_07.nc (file 223 of 312)
# Downloading SSHDYN_2010_08.nc (file 224 of 312)
# Downloading SSHDYN_2010_09.nc (file 225 of 312)
# Downloading SSHDYN_2010_10.nc (file 226 of 312)
# Downloading SSHDYN_2010_11.nc (file 227 of 312)
# Downloading SSHDYN_2010_12.nc (file 228 of 312)
# Downloading SSHDYN_2011_01.nc (file 229 of 312)
# Downloading SSHDYN_2011_02.nc (file 230 of 312)
# Downloading SSHDYN_2011_03.nc (file 231 of 312)
# Downloading SSHDYN_2011_04.nc (file 232 of 312)
# Downloading SSHDYN_2011_05.nc (file 233 of 312)
# Downloading SSHDYN_2011_06.nc (file 234 of 312)
# Downloading SSHDYN_2011_07.nc (file 235 of 312)
# Downloading SSHDYN_2011_08.nc (file 236 of 312)
# Downloading SSHDYN_2011_09.nc (file 237 of 312)
# Downloading SSHDYN_2011_10.nc (file 238 of 312)
# Downloading SSHDYN_2011_11.nc (file 239 of 312)
# Downloading SSHDYN_2011_12.nc (file 240 of 312)
# Downloading SSHDYN_2012_01.nc (file 241 of 312)
# Downloading SSHDYN_2012_02.nc (file 242 of 312)
# Downloading SSHDYN_2012_03.nc (file 243 of 312)
# Downloading SSHDYN_2012_04.nc (file 244 of 312)
# Downloading SSHDYN_2012_05.nc (file 245 of 312)
# Downloading SSHDYN_2012_06.nc (file 246 of 312)
# Downloading SSHDYN_2012_07.nc (file 247 of 312)
# Downloading SSHDYN_2012_08.nc (file 248 of 312)
# Downloading SSHDYN_2012_09.nc (file 249 of 312)
# Downloading SSHDYN_2012_10.nc (file 250 of 312)
# Downloading SSHDYN_2012_11.nc (file 251 of 312)
# Downloading SSHDYN_2012_12.nc (file 252 of 312)
# Downloading SSHDYN_2013_01.nc (file 253 of 312)
# Downloading SSHDYN_2013_02.nc (file 254 of 312)
# Downloading SSHDYN_2013_03.nc (file 255 of 312)
# Downloading SSHDYN_2013_04.nc (file 256 of 312)
# Downloading SSHDYN_2013_05.nc (file 257 of 312)
# Downloading SSHDYN_2013_06.nc (file 258 of 312)
# Downloading SSHDYN_2013_07.nc (file 259 of 312)
# Downloading SSHDYN_2013_08.nc (file 260 of 312)
# Downloading SSHDYN_2013_09.nc (file 261 of 312)
# Downloading SSHDYN_2013_10.nc (file 262 of 312)
# Downloading SSHDYN_2013_11.nc (file 263 of 312)
# Downloading SSHDYN_2013_12.nc (file 264 of 312)
# Downloading SSHDYN_2014_01.nc (file 265 of 312)
# Downloading SSHDYN_2014_02.nc (file 266 of 312)
# Downloading SSHDYN_2014_03.nc (file 267 of 312)
# Downloading SSHDYN_2014_04.nc (file 268 of 312)
# Downloading SSHDYN_2014_05.nc (file 269 of 312)
# Downloading SSHDYN_2014_06.nc (file 270 of 312)
# Downloading SSHDYN_2014_07.nc (file 271 of 312)
# Downloading SSHDYN_2014_08.nc (file 272 of 312)
# Downloading SSHDYN_2014_09.nc (file 273 of 312)
# Downloading SSHDYN_2014_10.nc (file 274 of 312)
# Downloading SSHDYN_2014_11.nc (file 275 of 312)
# Downloading SSHDYN_2014_12.nc (file 276 of 312)
# Downloading SSHDYN_2015_01.nc (file 277 of 312)
# Downloading SSHDYN_2015_02.nc (file 278 of 312)
# Downloading SSHDYN_2015_03.nc (file 279 of 312)
# Downloading SSHDYN_2015_04.nc (file 280 of 312)
# Downloading SSHDYN_2015_05.nc (file 281 of 312)
# Downloading SSHDYN_2015_06.nc (file 282 of 312)
# Downloading SSHDYN_2015_07.nc (file 283 of 312)
# Downloading SSHDYN_2015_08.nc (file 284 of 312)
# Downloading SSHDYN_2015_09.nc (file 285 of 312)
# Downloading SSHDYN_2015_10.nc (file 286 of 312)
# Downloading SSHDYN_2015_11.nc (file 287 of 312)
# Downloading SSHDYN_2015_12.nc (file 288 of 312)
# Downloading SSHDYN_2016_01.nc (file 289 of 312)
# Downloading SSHDYN_2016_02.nc (file 290 of 312)
# Downloading SSHDYN_2016_03.nc (file 291 of 312)
# Downloading SSHDYN_2016_04.nc (file 292 of 312)
# Downloading SSHDYN_2016_05.nc (file 293 of 312)
# Downloading SSHDYN_2016_06.nc (file 294 of 312)
# Downloading SSHDYN_2016_07.nc (file 295 of 312)
# Downloading SSHDYN_2016_08.nc (file 296 of 312)
# Downloading SSHDYN_2016_09.nc (file 297 of 312)
# Downloading SSHDYN_2016_10.nc (file 298 of 312)
# Downloading SSHDYN_2016_11.nc (file 299 of 312)
# Downloading SSHDYN_2016_12.nc (file 300 of 312)
# Downloading SSHDYN_2017_01.nc (file 301 of 312)
# Downloading SSHDYN_2017_02.nc (file 302 of 312)
# Downloading SSHDYN_2017_03.nc (file 303 of 312)
# Downloading SSHDYN_2017_04.nc (file 304 of 312)
# Downloading SSHDYN_2017_05.nc (file 305 of 312)
# Downloading SSHDYN_2017_06.nc (file 306 of 312)
# Downloading SSHDYN_2017_07.nc (file 307 of 312)
# Downloading SSHDYN_2017_08.nc (file 308 of 312)
# Downloading SSHDYN_2017_09.nc (file 309 of 312)
# Downloading SSHDYN_2017_10.nc (file 310 of 312)
# Downloading SSHDYN_2017_11.nc (file 311 of 312)
# Downloading SSHDYN_2017_12.nc (file 312 of 312)

# %% [markdown]
# Note: if the above cell fails before the download is complete, try re-running - often the API will reject downloads when there are too many pings in a given time interval.
